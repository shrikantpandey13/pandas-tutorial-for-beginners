# %%
how to create dataframe in pandas

how to create dataframe in pandas diffrent way

how to read csv file in pandas

how to  read excel file in pandas

# %%
import pandas as pd

# %%
std_names = ['karthik','Nikesh','Ram','Jai']

# %%
df = pd.DataFrame(std_names)
df
# Out:
#          0
# 0  karthik
# 1   Nikesh
# 2      Ram
# 3      Jai

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame(std_names, columns=['student_name'])
df
# Out:
#   student_name
# 0      karthik
# 1       Nikesh
# 2          Ram
# 3          Jai

# %%
names = ['karthik','Nikesh','Ram','Jai']

ages = [31,32,33,34]

locations = ["Delhi","Bangalore","Kolkata","Chaenai"]

data = list(zip(names,ages,locations ))
data

# data = list(zip(names,ages,locations))
# Out:
# [('karthik', 31, 'Delhi'),
#  ('Nikesh', 32, 'Bangalore'),
#  ('Ram', 33, 'Kolkata'),
#  ('Jai', 34, 'Chaenai')]

# %%
type(data)
# Out:
# list

# %%
df = pd.DataFrame(data, columns = ['std_name','std_ages','std_location'])
df
# Out:
#   std_name  std_ages std_location
# 0  karthik        31        Delhi
# 1   Nikesh        32    Bangalore
# 2      Ram        33      Kolkata
# 3      Jai        34      Chaenai

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['std_name', 'std_ages', 'std_location'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   std_name      4 non-null      object
#  1   std_ages      4 non-null      int64
#  2   std_location  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
data_dict = {"names":['karthik','Nikesh','Ram','Jai'],
       "ages":[31,32,33,34],
       "city":["Delhi","Bangalore","Kolkata","Chaenai"]}

# %%
df = pd.DataFrame(data_dict)
df
# Out:
#      names  ages       city
# 0  karthik    31      Delhi
# 1   Nikesh    32  Bangalore
# 2      Ram    33    Kolkata
# 3      Jai    34    Chaenai

# %%
df_csv = pd.read_csv("C:/Users/Shrikant/Desktop/Pandas tutorials for beginners/dataset/employees.csv")
df_csv
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male  03-04-2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df_csv.shape
# Out:
# (1000, 8)

# %%
df_csv.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df_result = df_csv[['Gender', 'Start Date', 'Last Login Time', 'Salary']]

# %%
df_result
# Out:
#      Gender  Start Date Last Login Time  Salary
# 0      Male  08-06-1993        12:42 PM   97308
# 1      Male   3/31/1996         6:53 AM   61933
# 2    Female   4/23/1993        11:17 AM  130590
# 3      Male  03-04-2005         1:00 PM  138705
# 4      Male   1/24/1998         4:47 PM  101004
# ..      ...         ...             ...     ...
# 995     NaN  11/23/2014         6:09 AM  132483
# 996    Male   1/31/1984         6:30 AM   42392
# 997    Male   5/20/2013        12:39 PM   96914
# 998    Male   4/20/2013         4:45 PM   60500
# 999    Male   5/15/2012         6:24 PM  129949
#
# [1000 rows x 4 columns]

# %%
df_csv.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 0    Douglas    Male  08-06-1993        12:42 PM   97308   6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3      Jerry    Male  03-04-2005         1:00 PM  138705   9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004   1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163  10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476  10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906  11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570  18.523
# 9    Frances  Female  08-08-2002         6:51 AM  139852   7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
df_csv.tail(10)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary   Bonus  \
# 990      Robin  Female   7/24/1987         1:35 PM  100765  10.982
# 991       Rose  Female   8/25/2002         5:12 AM  134505  11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769  11.625
# 993       Tina  Female   5/15/1997         3:53 PM   56450  19.040
# 994     George    Male   6/21/2013         5:47 PM   98874   4.479
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior Management                  Team
# 990              True       Client Services
# 991              True             Marketing
# 992              True               Finance
# 993              True           Engineering
# ...

# %%
df_csv.insert(2,column = "adddress", value = "aus")

# %%
df_csv.head()
# Out:
#   First Name  Gender adddress  Start Date Last Login Time  Salary   Bonus  \
# 0    Douglas    Male      aus  08-06-1993        12:42 PM   97308   6.945
# 1     Thomas    Male      aus   3/31/1996         6:53 AM   61933   4.170
# 2      Maria  Female      aus   4/23/1993        11:17 AM  130590  11.858
# 3      Jerry    Male      aus  03-04-2005         1:00 PM  138705   9.340
# 4      Larry    Male      aus   1/24/1998         4:47 PM  101004   1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df_csv['pincode'] = "453234"

# %%
df_csv.head()
# Out:
#   First Name  Gender adddress  Start Date Last Login Time  Salary   Bonus  \
# 0    Douglas    Male      aus  08-06-1993        12:42 PM   97308   6.945
# 1     Thomas    Male      aus   3/31/1996         6:53 AM   61933   4.170
# 2      Maria  Female      aus   4/23/1993        11:17 AM  130590  11.858
# 3      Jerry    Male      aus  03-04-2005         1:00 PM  138705   9.340
# 4      Larry    Male      aus   1/24/1998         4:47 PM  101004   1.389
#
#   Senior Management             Team pincode
# 0              True        Marketing  453234
# 1              True              NaN  453234
# 2             False          Finance  453234
# 3              True          Finance  453234
# 4              True  Client Services  453234

# %%
df_excel = pd.read_excel("C:/Users/Shrikant/Desktop/Pandas tutorials for beginners/dataset/Financial Sample.xlsx")

# %%
df_excel.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
df_excel.shape
# Out:
# (700, 16)
